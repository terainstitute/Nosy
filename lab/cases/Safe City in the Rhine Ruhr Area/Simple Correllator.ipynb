# %%
import pandas as pd
from itertools import combinations
from googlesearch import search

# %%
# First load all Comapnies & URLs to compat
sheets = ("./data/companies.csv", "./data/companies.csv")
dfs = []

for sheet in sheets:
    df = pd.read_csv(sheet)
    dfs.append(df)
    
df = pd.concat(dfs, axis=0, join='inner', ignore_index=False)

# importing product
from itertools import product
  
# apply product method
pairs  = list(product(df['name'], df['url']))

pairs[:5]
# Out:
# [('Huawei', 'huawei.com'),
#  ('Huawei', 'baesystems.com'),
#  ('Huawei', 'axis.com'),
#  ('Huawei', 'boschsecurity.com'),
#  ('Huawei', 'dahuasecurity.com')]

# %% [markdown]
# # Create all search queries to execute

# %%
for query in queries:
for i in range(100):
  for attempt in range(10):
    try:
      # do thing
    except:
      # perhaps reconnect, etc.
    else:
      break
  else:
    # we failed all the attempts - deal with the consequences.

for i in search (query, lang='de', tbs='0', safe='off', num=2, start=0, stop=3, pause=2.0):
 print(i)
# Out:
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
# ultimate fail
